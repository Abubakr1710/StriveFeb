# %%
import cv2
import matplotlib.pyplot as plt

# %%
cls=cv2.imread('images/hsv.png')

# %%
plt.figure(figsize=(20,15))
plt.imshow(cls)

# %%
cls_rgb=cv2.cvtColor(cls, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,15))
plt.imshow(cls_rgb)

# %% [markdown]
# ### We want to see only the BLUE ones

# %%
img=cv2.imread('images/m.jpg')
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(rgb_img)

lower_bound=(90,60,30)
upper_bound=(130,255,255)
mask=cv2.inRange(hsv_img, lower_bound, upper_bound)
masked_img=rgb_img.copy()
#masked_img[mask==0] = [0,0,0]
masked_img=cv2.bitwise_and(rgb_img, rgb_img, mask=mask)
plt.subplot(1,2,2)
plt.title('Only BLUE ones')
plt.imshow(masked_img)

# %% [markdown]
# ### We want now to see only the GREEN ones

# %%
img=cv2.imread('images/m.jpg')
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(rgb_img)

lower_bound=(35,30,10)
upper_bound=(85,255,255)
mask=cv2.inRange(hsv_img, lower_bound, upper_bound)
masked_img=rgb_img.copy()
#masked_img[mask==0] = [0,0,0]
masked_img=cv2.bitwise_and(rgb_img, rgb_img, mask=mask)
plt.subplot(1,2,2)
plt.title('Only BLUE ones')
plt.imshow(masked_img)

# %% [markdown]
# ### We want now to see the BLUE and GREEN ones in the same image

# %%
img=cv2.imread('images/m.jpg')
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(rgb_img)

lower_bound=(40,30,0)
upper_bound=(130,255,255)
mask=cv2.inRange(hsv_img, lower_bound, upper_bound)
masked_img=rgb_img.copy()
#masked_img[mask==0] = [0,0,0]
R,G,B = rgb_img
masked_img=cv2.bitwise_and(rgb_img, rgb_img, mask=mask)
plt.subplot(1,2,2)
plt.title('Only BLUE ones')
plt.imshow(masked_img)

# %% [markdown]
# ### For extra points: we want to see the BLUE, GREEN, and REDs and the rest should not be completely blacked out but faded out so we can still see them

# %%
img=cv2.imread('images/m.jpg')
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.figure(figsize=(20,15))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(rgb_img)

lower_bound=(0,0,10)
upper_bound=(255,255,255)
mask=cv2.inRange(hsv_img, lower_bound, upper_bound)
masked_img=rgb_img.copy()
#masked_img[mask==0] = [0,0,0]
masked_img=cv2.bitwise_and(rgb_img, rgb_img, mask=mask)
plt.subplot(1,2,2)
plt.title('Only BLUE ones')
plt.imshow(masked_img)
