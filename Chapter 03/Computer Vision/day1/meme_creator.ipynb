# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images/minion.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cimg= rgb_img.copy()
plt.figure(figsize=(20,15))
cv2.putText(cimg,'space and comma when I forgot them 500 line of code', (95,15), cv2.FONT_HERSHEY_COMPLEX,0.5, (255,255,255))
plt.imshow(cimg)
plt.savefig('meme.png')
