# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('images/m.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,10))
plt.imshow(rgb_img)

# %%
hsv_colors=cv2.cvtColor(hsv_colors, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,10))
plt.imshow(hsv_colors)

# %% [markdown]
# ### We want to see only the BLUE ones

# %%
img=cv2.imread('images/m.jpg')
rgb_img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#plt.figure(figsize=(10,8))
plt.figure(figsize=(16,10))
plt.subplot(1,2,1)
plt.title('original')
plt.imshow(rgb_img)

lower_bounds=(0,50,0)
upper_bound=(20,255,255)
mask=cv2.inRange(rgb_img,lower_bounds,upper_bound)
bns=cv2.bitwise_and(rgb_img, rgb_img, mask=mask)
plt.subplot(1,2,2)
plt.title('Only BLUE ones')
plt.imshow(bns)
plt.show()
